# %% [markdown]
# <h1>Soil moisture data analysis</h1>

# %%
import pandas as pd
import numpy as np 
import plotly.express as px

# %%
# Volumetric soil moisture
path_smvol_data = "C:/pale-blue-dot-challenge/data/g4.areaAvgTimeSeries.LPRM_AMSR2_A_SOILM3_001_soil_moisture_c1.20120703-20231222.180W_90S_180E_90N.csv"
smvol_data = pd.read_csv(path_smvol_data, skiprows=9,  usecols=[0,1], names=['Time','Soil moisture volume percentage'])

# %%
px.line(smvol_data, x="Time", y="Soil moisture volume percentage")

# %%
# Surface soil wetness
path_sw_data = "C:/pale-blue-dot-challenge/data/g4.areaAvgTimeSeries.M2TMNXLND_5_12_4_GWETTOP.19800101-20231130.180W_90S_180E_90N.csv"
sw_data = pd.read_csv(path_sw_data, skiprows=9,  usecols=[0,1], names=['Time','Surface soil wetness'])

# %%
px.line(sw_data, x="Time", y="Surface soil wetness")
